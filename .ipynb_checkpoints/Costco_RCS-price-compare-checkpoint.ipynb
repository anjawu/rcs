# %%
# working with dataframes
import pandas as pd
import numpy as np

# using spaCy to compare similarities in sentences
import spacy

# removing connecting words:
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize

# visualizations
import seaborn as sns                  # visualization (based on matplotlib)
import matplotlib.pyplot as plt        # visualization
from matplotlib.pyplot import figure

# math operations (e.g. isnan())
import math
import statistics
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anjawu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/anjawu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# NLTK resources used:
# https://www.nltk.org/install.html
# https://stackoverflow.com/questions/65199011/is-there-a-way-to-check-similarity-between-two-full-sentences-in-python
# https://www.programiz.com/python-programming/methods/string/lower
# https://betterprogramming.pub/the-beginners-guide-to-similarity-matching-using-spacy-782fc2922f7c
# https://stackabuse.com/removing-stop-words-from-strings-in-python/#usingpythonsnltklibrary
# https://www.nltk.org/api/nltk.tokenize.html

# %% [markdown]
# # Data collection and combination

# %%
# import all of costco coupons unedited
costco_nov8 = pd.read_csv('CSVs/costco/costco-couponsNov8.csv')
costco_feb28 = pd.read_csv('CSVs/costco/costco-couponsFeb28.csv')
costco_may30 = pd.read_csv('CSVs/costco/costco-couponsMay30.csv')

# import all of costco coupons edited by hand to make new column for just brands
strip_costco_nov8 = pd.read_csv('CSVs/costco/editted/strippedbrand-costco-couponsNov8.csv')
strip_costco_feb28 = pd.read_csv('CSVs/costco/editted/strippedbrand-costco-couponsFeb28.csv')
strip_costco_may30 = pd.read_csv('CSVs/costco/editted/strippedbrand-costco-couponsMay30.csv')

# import all of real-canadian superstore matches to costco coupons unedited
rcs_costco_nov8 = pd.read_csv('CSVs/rcss_costco_Nov8.csv')
rcs_costco_feb28 = pd.read_csv('CSVs/rcss_costco_Feb28.csv')
rcs_costco_may30 = pd.read_csv('CSVs/rcss_costco_May30.csv')

# import all of real-canadian superstore matches to costco coupons from edited version of costco csv
strip_rcs_costco_nov8 = pd.read_csv('CSVs/strippedbrand-rcss_costco_Nov8.csv')
strip_rcs_costco_feb28 = pd.read_csv('CSVs/strippedbrand-rcss_costco_Feb28.csv')
strip_rcs_costco_may30 = pd.read_csv('CSVs/strippedbrand-rcss_costco_May30.csv')

# %% [markdown]
# ### Combining and Cleaning DataFrames

# %%
# creating one df for each of the four sections above to combine dates into one
costco_frames = [costco_nov8, costco_feb28, costco_may30]
costco = pd.concat(costco_frames)

strip_costco_frames = [strip_costco_nov8, strip_costco_feb28, strip_costco_may30]
stripped_costco = pd.concat(strip_costco_frames)

rcs_costco_frames = [rcs_costco_nov8, rcs_costco_feb28, rcs_costco_may30]
rcs_costco = pd.concat(rcs_costco_frames)

strip_rcs_costco_frames = [strip_rcs_costco_nov8, strip_rcs_costco_feb28, strip_rcs_costco_may30]
stripped_rcs_costco = pd.concat(strip_rcs_costco_frames)

# %%
costco.shape
# Out:
# (144, 6)

# %%
# cleaning up 
rcs_costco = rcs_costco.reset_index()
stripped_rcs_costco = stripped_rcs_costco.reset_index()
rcs_costco = rcs_costco.drop(['index', 'Unnamed: 0'], axis=1)
stripped_rcs_costco = stripped_rcs_costco.drop(['index', 'Unnamed: 0'], axis=1)

# %%
rcs_costco
# Out:
#                                           Costco-Item Costco-Price  \
# 0                                 Salton glass kettle      $34.99
# 1                      Gillette Fusion ProGlide Power      $49.99
# 2                         Bio-Oil skin care treatment      $19.99
# 3              Tide Pods with Downy laundry detergent      $20.99
# 4                    Tide HE liquid laundry detergent      $18.99
# 5                    Lindt Lindor assorted chocolates      $17.49
# 6             Webber Naturals triple strength Omega-3      $23.99
# 7                                  Jamieson probiotic      $23.99
# 8        Jamieson B100 complex timed-release vitamins      $20.99
# 9                           Samsung 75-in. television    $1,689.99
# 10                  Lorex 8 channel DVR camera system      $399.99
# 11                                 Details accent mat       $16.99
# 12          Starbucks Caffè Verona\nwhole-bean coffee       $17.99
# 13  Maple Leaf Natural Selections sliced oven roas...       $13.99
# 14     Downy Unstopables Fresh\nin-wash scent booster       $15.99
# 15                                Glysomed hand cream       $11.89
# 16  Kirkland Signature multivitamin and minerals f...       $15.99
# 17                 Sponge Towels Premium paper towels       $17.99
# 18                                      Puma backpack       $23.99
# 19                    Microsoft Surface Pro 7+ bundle      $999.99
# 20            HP 14 in. touchscreen laptop, i5-1155G7      $699.99
# 21                Philips OneBlade face & body shaver       $39.99
# 22             Van Houtte original house blend coffee       $33.99
# 23                Folgers classic roast ground coffee        $8.69
# 24                        Nescafé Rich instant coffee        $8.49
# 25                                 No sugar keto bars       $15.99
# 26                    Jack Link's teriyaki beef jerky       $11.49
# 27                         Clif Builders protein bars       $16.49
# 28                  Crunchmaster multi-grain crackers        $6.49
# 29                            Kellogg’s Vector cereal        $7.99
# 30                    Kellogg's Frosted Flakes cereal        $6.99
# 31   San Pellegrino Naturali Italian sparkling drinks       $14.99
# 32                       Splenda no calorie sweetener       $19.99
# 33                      Olive Garden Italian dressing        $7.99
# 34                  Beyond Burger plant-based burgers       $14.99
# 35                                     Activia yogurt        $7.49
# 36                         Align probiotic supplement       $39.99
# 37                Kirkland Signature omega-3 fish oil       $19.99
# 38                                RestoraLAX laxative       $30.99
# 39  Dove Men + Care Clean Comfort dry antiperspira...       $12.99
# 40                   Dove Men + Care Extra Fresh bars       $12.99
# 41                      Hydrasense eye drops advanced       $18.99
# 42     Jamieson calcium and magnesium with vitamin D3        $7.99
# 43                          Webber Naturals melatonin        $9.99
# 44          Olay Total Effects nourishing moisturizer       $28.99
# 45                     Aveeno stress relief body wash       $14.99
# 46                         G.U.M. Soft-Picks Advanced       $13.99
# 47                     Gillette Fusion ProGlide Power       $53.99
# 48                      Vaseline Cocoa Radiant lotion        $8.99
# 49      Downy Unstopables Fresh in-wash scent booster       $17.49
# 50               Gain original liquid fabric softener       $14.49
# 51                         Swiffer dry or wet refills       $15.99
# 52               Mr. Clean Magic Eraser cleaning pads        $9.99
# 53                         Cesar Entrées wet dog food       $29.59
#
#           RCS-Brand                                           RCS-Item  \
# 0               NaN               Salton - 1.5 L Cordless Glass Kettle
# 1          Gillette               Fusion Proglide Cartridges Microcomb
# 2               NaN  Argan Queen Argan Oil for Hair Nails and Skin ...
# 3              Tide  With Downy, Liquid Laundry Detergent Pods, Apr...
# 4              Tide  Tide Liquid Laundry Detergent, Original, 80 lo...
# 5             Lindt                Chocolate, Lindor Assorted Truffles
# 6   Webber Naturals                           Omega-3, Triple Strength
# 7          Jamieson                                Probiotic 5 Billion
# 8          Jamieson                  B100 Complex 100mg, Timed Release
# 9               NaN  Mount-It MI-346L 17.3 in Articulating Full Mot...
# 10              NaN      Lorex wireless security system with 4 cameras
# 11              NaN  Custom Printed Rugs DM 62 Lambson Moose Intrud...
# 12        Starbucks  Caffè Verona Capsules, Ground Coffee For Nespr...
# 13       Maple Leaf     Natural Selections Oven Roasted Chicken Breast
# 14            Downy  Downy Unstopables In-Wash Scent Booster Beads,...
# 15         Glysomed                                         Hand Cream
# 16     PC Blue Menu  Thin & Crispy Vegetables, Spinach And Goat Che...
# 17              NaN  Swedish Dishcloth Cellulose Sponge Cloth Reusa...
# 18              NaN                           Puma Style Camo Backpack
# 19              NaN     Satechi Type-C Multimedia Adapter (Space Grey)
# 20              NaN  HP EliteBook x360 1040 G8 14" Touchscreen 2 in...
# 21              NaN  Philips - Cordless Electric Face and Body Trim...
# 22           Keurig       Van Houtte Original House Blend Medium Roast
# 23          Folgers                        Classic Roast Ground Coffee
# 24          Nescafe  Nescafé Sweet and Creamy Original Instant Coff...
# 25       Vegan Pure                                  No Sugar Keto Bar
# 26       Jack Links                               Beef Jerky, Teriyaki
# 27             Clif     Builders Protein Builder's Bar, Chocolate Mint
# 28     PC Blue Menu                   Butter Flavour Microwave Popcorn
# 29         Kelloggs                     Vector Meal Replacement Cereal
# 30         Kelloggs                                     Fun Pac Cereal
# 31   San Pellegrino    Naturali Pompelmo Sparkling Grapefruit Beverage
# 32          Splenda                                           Granular
# 33     Olive Garden                                   Italian Dressing
# 34      Beyond Meat                          Beyond Burger Plant-Based
# 35          Activia  Probiotic Yogurt, Strawberry/Blueberry/Raspber...
# 36            Align             Daily Probiotic Supplement, 50 Gummies
# 37     PC Blue Menu                                      Eggs, Omega-3
# 38       Restoralax  Powder Laxative, Effective Relief, No Taste, N...
# 39             Dove    Men+Care Dry Spray Antiperspirant CleanComfort
# 40             Dove  Men+Care Body And Face Bar for Refreshed Skin ...
# 41       Hydrasense  Advanced Eye Drops, For Dry Eyes, Preservative...
# 42         Jamieson                  Calcium Magnesium with Vitamin D3
# 43  Webber Naturals                   Melatonin 10mg, Maximum Strength
# 44             Olay  Total Effects Nourishing Cream Cleanser Face W...
# 45           Aveeno                            Stress Relief Body Wash
# 46              Gum                  Soft-Picks Advanced Dental Picks
# 47         Gillette               Fusion Proglide Cartridges Microcomb
# 48         Vaseline       Men Intensive Care Body Lotion Cocoa Radiant
# 49            Downy      Unstopable In-Wash Scent Booster Beads, Fresh
# 50             Gain  Fabric Softener, Original, 120 Loads, He Compa...
# 51          Swiffer  Sweeper Dry + Wet Sweeping Kit 1 Sweeper, 7 Dr...
# 52        Mr. Clean                                       Magic Eraser
# 53              NaN       CESAR® ENTRÉES FILET MIGNON FLAVOUR 100g 1Pc
#
#     RCS-Price RCS-Unit Price RCS-Unit Measure
# 0      $62.33            NaN              NaN
# 1      $44.99          $5.62            / 1ea
# 2      $22.00            NaN              NaN
# 3      $23.99          $1.51           / 100g
# 4      $19.99          $0.59          / 100ml
# 5       $9.99          $4.16           / 100g
# 6      $16.11          $0.20            / 1ea
# 7      $16.49          $0.23            / 1ea
# 8      $22.99          $0.19            / 1ea
# 9     $200.37            NaN              NaN
# 10    $274.99            NaN              NaN
# 11     $25.37            NaN              NaN
# 12      $9.99          $9.99           / 100g
# 13      $6.49         $37.09            / 1kg
# 14      $9.99          $3.51           / 100g
# 15      $6.99          $4.66          / 100ml
# 16      $3.29          $0.91           / 100g
# 17      $9.99            NaN              NaN
# 18     $39.25            NaN              NaN
# 19    $156.19            NaN              NaN
# 20  $2,786.06            NaN              NaN
# 21     $99.97            NaN              NaN
# 22     $10.99          $0.92            / 1ea
# 23      $7.99          $0.87           / 100g
# 24      $7.49          $2.13           / 100g
# 25     $11.99          $7.49           / 100g
# 26      $6.99          $8.74           / 100g
# 27      $2.19          $3.22           / 100g
# 28      $4.29          $0.89           / 100g
# 29      $9.49          $1.12           / 100g
# 30      $5.49          $2.61           / 100g
# 31      $5.99          $0.30          / 100ml
# 32      $6.29          $5.72           / 100g
# 33      $4.89          $1.03          / 100ml
# 34      $7.49          $3.31           / 100g
# 35      $5.99          $0.50           / 100g
# 36     $24.49          $0.49            / 1ea
# 37      $0.99          $1.13           / 100g
# 38     $34.49          $4.51           / 100g
# 39      $4.00         $14.29           / 100g
# 40      $6.49          $2.04           / 100g
# 41     $21.99        $109.95          / 100ml
# 42     $11.49          $0.06            / 1ea
# 43     $10.11          $0.14            / 1ea
# 44     $11.99          $7.99          / 100ml
# 45      $9.99          $1.88          / 100ml
# 46      $7.99          $0.13            / 1ea
# 47     $44.99          $5.62            / 1ea
# 48      $6.99          $2.37          / 100ml
# 49     $14.99          $3.55           / 100g
# 50     $12.99          $0.43          / 100ml
# 51     $17.99         $17.99            / 1ea
# 52      $3.99          $2.00            / 1ea
# 53     $10.23            NaN              NaN

# %%
stripped_rcs_costco
# Out:
#                   Costco-Brand                      Costco-Item Costco-Price  \
# 0                    FoodSaver         food preservation system     $119.99
# 1                       Salton                     glass kettle      $34.99
# 2              Comfort Grande                       foam pillow      $27.99
# 3    Elizabeth Arden Millenium        day, night and eye creams      $34.99
# 4                Charmin Blue        Ultra Soft bathroom tissue      $19.99
# ..                         ...                              ...          ...
# 101                      Gain   original liquid fabric softener      $14.49
# 102                   Swiffer                dry or wet refills      $15.99
# 103                 Mr. Clean        Magic Eraser cleaning pads       $9.99
# 104              Cesar Entrees                     wet dog food      $29.59
# 105             Zoe Super Bars      salmon flavoured dog treats      $15.99
#
#               RCS-Brand                                           RCS-Item  \
# 0                   NaN  Beverage Dispenser Gradient Red Water-Colour (...
# 1        Hamilton Beach                                  Glass Kettle, 1 l
# 2                   NaN                                   The Ploom Pillow
# 3          LOreal Paris  Skin Expertise Collagen Moisture Filler Day/Ni...
# 4               Kleenex  Ultra Soft Facial Tissues, 16 Flat Boxes, 3-Pl...
# ..                  ...                                                ...
# 101                Gain  Fabric Softener, Original, 120 Loads, He Compa...
# 102             Swiffer  Sweeper Dry + Wet Sweeping Kit 1 Sweeper, 7 Dr...
# 103           Mr. Clean                                       Magic Eraser
# 104  President's Choice   Dog Food, Extra Meaty Beef Bacon & Cheese Dinner
# 105              Purina    One Dog Treats, True Instinct Bites with Salmon
#
#     RCS-Price RCS-Unit Price RCS-Unit Measure
# 0      $34.95            NaN              NaN
# 1      $39.99         $39.99            / 1ea
# 2      $99.00            NaN              NaN
# 3      $22.99         $45.98          / 100ml
# 4      $19.99          $0.02            / 1ea
# ..        ...            ...              ...
# 101    $12.99          $0.43          / 100ml
# 102    $17.99         $17.99            / 1ea
# 103     $3.99          $2.00            / 1ea
# 104     $2.09          $0.56           / 100g
# 105     $5.29          $2.67           / 100g
#
# [106 rows x 8 columns]

# %% [markdown]
# ------

# %% [markdown]
# # Analyzing items

# %% [markdown]
# ## Calculating number of hits (for brands stripped vs brands included)

# %% [markdown]
# Count items returned for each df

# %%
print(f'number of items compared in stores with brandname in item name: {len(rcs_costco.index)} \nnumber of items compared in stores with NO brandname in item name: {len(stripped_rcs_costco.index)}')
# Out:
# number of items compared in stores with brandname in item name: 54
# number of items compared in stores with NO brandname in item name: 106

# %%
print(f'The number of items returned without including brand is {len(stripped_rcs_costco.index)/len(rcs_costco.index)}X the amount with the brand name in the search')
# Out:
# The number of items returned without including brand is 1.962962962962963X the amount with the brand name in the search

# %% [markdown]
# As can be seen the items with no brand name return more matches between stores (almost 2 times more). However, this might not be a good thing because the matches could potentially be worse. This is the next part that we must analyze: how many of the hits were correct (for both the stripped and non-stripped dataframe)

# %% [markdown]
# ## Calculating number of correct hits

# %% [markdown]
# - ensure all sentences are lower case for comparison
# - drop stop words: "the, and, etc." **Concat into singular string per item**

# %% [markdown]
# ### No Brand DF (i.e. stripped):

# %% [markdown]
# #### Cleaning the sentences to be lower case
# - iloc[row][column] --> [i][1] and [i][4]
# - .lower() to lower sentence

# %%
# getting number of rows from dataframe
length = len(stripped_rcs_costco.index)

# creating empty lists to store lowercase sentences for both Costco and RCS items
lowercase_RCS = []
lowercase_Costco = []

# iterating through each row and selecting just the item name to become lowercase
for i in range(length):
    lowercase_Costco.append(stripped_rcs_costco.iloc[i][1].lower())
    lowercase_RCS.append(stripped_rcs_costco.iloc[i][4].lower())

# creating column to store lower case item names
stripped_rcs_costco['lowercase_Costco'] = lowercase_Costco
stripped_rcs_costco['lowercase_RCS'] = lowercase_RCS

# %% [markdown]
# #### Removing unimportant connector words (aka stopwords)
# method 1: https://stackabuse.com/removing-stop-words-from-strings-in-python/#usingpythonsnltklibrary
# method 2: https://stackabuse.com/removing-stop-words-from-strings-in-python/#usingthespacylibrary:~:text=Using%20the%20SpaCy%20Library

# %%
no_sw_costco = []
no_sw_rcs = []

for costco_item in stripped_rcs_costco['lowercase_Costco']:
    # tokenizing words to be able to numerically compare to nltk stopword list
    text_tokens_costco = word_tokenize(costco_item)
    # iterating through each word in sentence to pull out words that are NOT in stop words
    tokens_without_sw_costco = [word for word in text_tokens_costco if not word in stopwords.words()]
    # create string to combine words pulled out from the text_tokens
    single_string_no_sw_costco = ""
    # looping through each word within the phrase analyzed to remove stop words and combining it to one string
    for word in tokens_without_sw_costco:
        single_string_no_sw_costco = single_string_no_sw_costco + " "  + word
    # adding only words (combined to from 1 string) not found in stopwords to list created above
    no_sw_costco.append(single_string_no_sw_costco)

# repeating above steps but fro items from RCS
for rcs_item in stripped_rcs_costco['lowercase_RCS']:
    text_tokens_rcs = word_tokenize(rcs_item)
    tokens_without_sw_rcs = [word for word in text_tokens_rcs if not word in stopwords.words()]
    single_string_no_sw_rcs = ""
    for word in tokens_without_sw_rcs:
        single_string_no_sw_rcs = single_string_no_sw_rcs + " "  + word
    no_sw_rcs.append(single_string_no_sw_rcs)
    
# creating columns for both Costco and RCS items without stop words that have all lowercase words.
stripped_rcs_costco['no_sw_Costco'] = no_sw_costco
stripped_rcs_costco['no_sw_RCS'] = no_sw_rcs
# stripped_rcs_costco

# %% [markdown]
# #### Sentence comparison
# Here we will look at the percentage of similarities in sentences for the same costco vs rcs item
#
# Resource: https://stackoverflow.com/questions/65199011/is-there-a-way-to-check-similarity-between-two-full-sentences-in-python

# %%
nlp = spacy.load("en_core_web_lg")

# %%
# getting number of rows from dataframe
length = len(stripped_rcs_costco.index)

# creating empty lists to store the similarity of the sentences from both Costco and RCS items
lowercase_item_similarity = []
no_sw_item_similarity = []

# iterating through each row and comparing the "same" item from Costco and RCS
for i in range(length):
    lowercase_item_similarity.append(nlp(stripped_rcs_costco.iloc[i][8]).similarity(nlp(stripped_rcs_costco.iloc[i][9])))
    no_sw_item_similarity.append(nlp(stripped_rcs_costco.iloc[i][10]).similarity(nlp(stripped_rcs_costco.iloc[i][11])))

    
stripped_rcs_costco['lowercase_item_similarity'] = lowercase_item_similarity
stripped_rcs_costco['no_sw_item_similarity'] = no_sw_item_similarity
# stripped_rcs_costco

# %% [markdown]
# ### Branded DF:

# %% [markdown]
# #### Completing the same process as for the non-branded (stripped) dataframe:
# - creating lowercase columns for both costco and rcs
# - creating 2 columns for singular item string containing no stopwords
# - comparing sentence similarity for both above points

# %% [markdown]
# #### lowercase for all items:

# %%
# getting number of rows from dataframe
length = len(rcs_costco.index)

# creating empty lists to store lowercase sentences for both Costco and RCS items
lowercase_rcs = []
lowercase_costco = []

# iterating through each row and selecting just the item name to become lowercase
for i in range(length):
    lowercase_costco.append(rcs_costco.iloc[i][0].lower())
    lowercase_rcs.append(rcs_costco.iloc[i][3].lower())

# creating column to store lower case item names
rcs_costco['lowercase_Costco'] = lowercase_costco
rcs_costco['lowercase_RCS'] = lowercase_rcs

# %% [markdown]
# #### Removing stop words:

# %%
no_sw_costco = []
no_sw_rcs = []

for costco_item in rcs_costco['lowercase_Costco']:
    # tokenizing words to be able to numerically compare to nltk stopword list
    text_tokens_costco = word_tokenize(costco_item)
    # iterating through each word in sentence to pull out words that are NOT in stop words
    tokens_without_sw_costco = [word for word in text_tokens_costco if not word in stopwords.words()]
    # create string to combine words pulled out from the text_tokens
    single_string_no_sw_costco = ""
    # looping through each word within the phrase analyzed to remove stop words and combining it to one string
    for word in tokens_without_sw_costco:
        single_string_no_sw_costco = single_string_no_sw_costco + " "  + word
    # adding only words (combined to from 1 string) not found in stopwords to list created above
    no_sw_costco.append(single_string_no_sw_costco)

# repeating above steps but fro items from RCS
for rcs_item in rcs_costco['lowercase_RCS']:
    text_tokens_rcs = word_tokenize(rcs_item)
    tokens_without_sw_rcs = [word for word in text_tokens_rcs if not word in stopwords.words()]
    single_string_no_sw_rcs = ""
    for word in tokens_without_sw_rcs:
        single_string_no_sw_rcs = single_string_no_sw_rcs + " "  + word
    no_sw_rcs.append(single_string_no_sw_rcs)
    
# creating columns for both Costco and RCS items without stop words that have all lowercase words.
rcs_costco['no_sw_Costco'] = no_sw_costco
rcs_costco['no_sw_RCS'] = no_sw_rcs
rcs_costco
# Out:
#                                           Costco-Item Costco-Price  \
# 0                                 Salton glass kettle      $34.99
# 1                      Gillette Fusion ProGlide Power      $49.99
# 2                         Bio-Oil skin care treatment      $19.99
# 3              Tide Pods with Downy laundry detergent      $20.99
# 4                    Tide HE liquid laundry detergent      $18.99
# 5                    Lindt Lindor assorted chocolates      $17.49
# 6             Webber Naturals triple strength Omega-3      $23.99
# 7                                  Jamieson probiotic      $23.99
# 8        Jamieson B100 complex timed-release vitamins      $20.99
# 9                           Samsung 75-in. television    $1,689.99
# 10                  Lorex 8 channel DVR camera system      $399.99
# 11                                 Details accent mat       $16.99
# 12          Starbucks Caffè Verona\nwhole-bean coffee       $17.99
# 13  Maple Leaf Natural Selections sliced oven roas...       $13.99
# 14     Downy Unstopables Fresh\nin-wash scent booster       $15.99
# 15                                Glysomed hand cream       $11.89
# 16  Kirkland Signature multivitamin and minerals f...       $15.99
# 17                 Sponge Towels Premium paper towels       $17.99
# 18                                      Puma backpack       $23.99
# 19                    Microsoft Surface Pro 7+ bundle      $999.99
# 20            HP 14 in. touchscreen laptop, i5-1155G7      $699.99
# 21                Philips OneBlade face & body shaver       $39.99
# 22             Van Houtte original house blend coffee       $33.99
# 23                Folgers classic roast ground coffee        $8.69
# 24                        Nescafé Rich instant coffee        $8.49
# 25                                 No sugar keto bars       $15.99
# 26                    Jack Link's teriyaki beef jerky       $11.49
# 27                         Clif Builders protein bars       $16.49
# 28                  Crunchmaster multi-grain crackers        $6.49
# 29                            Kellogg’s Vector cereal        $7.99
# 30                    Kellogg's Frosted Flakes cereal        $6.99
# 31   San Pellegrino Naturali Italian sparkling drinks       $14.99
# 32                       Splenda no calorie sweetener       $19.99
# 33                      Olive Garden Italian dressing        $7.99
# 34                  Beyond Burger plant-based burgers       $14.99
# 35                                     Activia yogurt        $7.49
# 36                         Align probiotic supplement       $39.99
# 37                Kirkland Signature omega-3 fish oil       $19.99
# 38                                RestoraLAX laxative       $30.99
# 39  Dove Men + Care Clean Comfort dry antiperspira...       $12.99
# 40                   Dove Men + Care Extra Fresh bars       $12.99
# 41                      Hydrasense eye drops advanced       $18.99
# 42     Jamieson calcium and magnesium with vitamin D3        $7.99
# 43                          Webber Naturals melatonin        $9.99
# 44          Olay Total Effects nourishing moisturizer       $28.99
# 45                     Aveeno stress relief body wash       $14.99
# 46                         G.U.M. Soft-Picks Advanced       $13.99
# 47                     Gillette Fusion ProGlide Power       $53.99
# 48                      Vaseline Cocoa Radiant lotion        $8.99
# 49      Downy Unstopables Fresh in-wash scent booster       $17.49
# 50               Gain original liquid fabric softener       $14.49
# 51                         Swiffer dry or wet refills       $15.99
# 52               Mr. Clean Magic Eraser cleaning pads        $9.99
# 53                         Cesar Entrées wet dog food       $29.59
#
#           RCS-Brand                                           RCS-Item  \
# 0               NaN               Salton - 1.5 L Cordless Glass Kettle
# 1          Gillette               Fusion Proglide Cartridges Microcomb
# 2               NaN  Argan Queen Argan Oil for Hair Nails and Skin ...
# 3              Tide  With Downy, Liquid Laundry Detergent Pods, Apr...
# 4              Tide  Tide Liquid Laundry Detergent, Original, 80 lo...
# 5             Lindt                Chocolate, Lindor Assorted Truffles
# 6   Webber Naturals                           Omega-3, Triple Strength
# 7          Jamieson                                Probiotic 5 Billion
# 8          Jamieson                  B100 Complex 100mg, Timed Release
# 9               NaN  Mount-It MI-346L 17.3 in Articulating Full Mot...
# 10              NaN      Lorex wireless security system with 4 cameras
# 11              NaN  Custom Printed Rugs DM 62 Lambson Moose Intrud...
# 12        Starbucks  Caffè Verona Capsules, Ground Coffee For Nespr...
# 13       Maple Leaf     Natural Selections Oven Roasted Chicken Breast
# 14            Downy  Downy Unstopables In-Wash Scent Booster Beads,...
# 15         Glysomed                                         Hand Cream
# 16     PC Blue Menu  Thin & Crispy Vegetables, Spinach And Goat Che...
# 17              NaN  Swedish Dishcloth Cellulose Sponge Cloth Reusa...
# 18              NaN                           Puma Style Camo Backpack
# 19              NaN     Satechi Type-C Multimedia Adapter (Space Grey)
# 20              NaN  HP EliteBook x360 1040 G8 14" Touchscreen 2 in...
# 21              NaN  Philips - Cordless Electric Face and Body Trim...
# 22           Keurig       Van Houtte Original House Blend Medium Roast
# 23          Folgers                        Classic Roast Ground Coffee
# 24          Nescafe  Nescafé Sweet and Creamy Original Instant Coff...
# 25       Vegan Pure                                  No Sugar Keto Bar
# 26       Jack Links                               Beef Jerky, Teriyaki
# 27             Clif     Builders Protein Builder's Bar, Chocolate Mint
# 28     PC Blue Menu                   Butter Flavour Microwave Popcorn
# 29         Kelloggs                     Vector Meal Replacement Cereal
# 30         Kelloggs                                     Fun Pac Cereal
# 31   San Pellegrino    Naturali Pompelmo Sparkling Grapefruit Beverage
# 32          Splenda                                           Granular
# 33     Olive Garden                                   Italian Dressing
# 34      Beyond Meat                          Beyond Burger Plant-Based
# 35          Activia  Probiotic Yogurt, Strawberry/Blueberry/Raspber...
# 36            Align             Daily Probiotic Supplement, 50 Gummies
# 37     PC Blue Menu                                      Eggs, Omega-3
# 38       Restoralax  Powder Laxative, Effective Relief, No Taste, N...
# 39             Dove    Men+Care Dry Spray Antiperspirant CleanComfort
# 40             Dove  Men+Care Body And Face Bar for Refreshed Skin ...
# 41       Hydrasense  Advanced Eye Drops, For Dry Eyes, Preservative...
# 42         Jamieson                  Calcium Magnesium with Vitamin D3
# 43  Webber Naturals                   Melatonin 10mg, Maximum Strength
# 44             Olay  Total Effects Nourishing Cream Cleanser Face W...
# 45           Aveeno                            Stress Relief Body Wash
# 46              Gum                  Soft-Picks Advanced Dental Picks
# 47         Gillette               Fusion Proglide Cartridges Microcomb
# 48         Vaseline       Men Intensive Care Body Lotion Cocoa Radiant
# 49            Downy      Unstopable In-Wash Scent Booster Beads, Fresh
# 50             Gain  Fabric Softener, Original, 120 Loads, He Compa...
# 51          Swiffer  Sweeper Dry + Wet Sweeping Kit 1 Sweeper, 7 Dr...
# 52        Mr. Clean                                       Magic Eraser
# 53              NaN       CESAR® ENTRÉES FILET MIGNON FLAVOUR 100g 1Pc
#
#     RCS-Price RCS-Unit Price RCS-Unit Measure  \
# 0      $62.33            NaN              NaN
# 1      $44.99          $5.62            / 1ea
# 2      $22.00            NaN              NaN
# 3      $23.99          $1.51           / 100g
# 4      $19.99          $0.59          / 100ml
# 5       $9.99          $4.16           / 100g
# 6      $16.11          $0.20            / 1ea
# 7      $16.49          $0.23            / 1ea
# 8      $22.99          $0.19            / 1ea
# 9     $200.37            NaN              NaN
# 10    $274.99            NaN              NaN
# 11     $25.37            NaN              NaN
# 12      $9.99          $9.99           / 100g
# 13      $6.49         $37.09            / 1kg
# 14      $9.99          $3.51           / 100g
# 15      $6.99          $4.66          / 100ml
# 16      $3.29          $0.91           / 100g
# 17      $9.99            NaN              NaN
# 18     $39.25            NaN              NaN
# 19    $156.19            NaN              NaN
# 20  $2,786.06            NaN              NaN
# 21     $99.97            NaN              NaN
# 22     $10.99          $0.92            / 1ea
# 23      $7.99          $0.87           / 100g
# 24      $7.49          $2.13           / 100g
# 25     $11.99          $7.49           / 100g
# 26      $6.99          $8.74           / 100g
# 27      $2.19          $3.22           / 100g
# 28      $4.29          $0.89           / 100g
# 29      $9.49          $1.12           / 100g
# 30      $5.49          $2.61           / 100g
# 31      $5.99          $0.30          / 100ml
# 32      $6.29          $5.72           / 100g
# 33      $4.89          $1.03          / 100ml
# 34      $7.49          $3.31           / 100g
# 35      $5.99          $0.50           / 100g
# 36     $24.49          $0.49            / 1ea
# 37      $0.99          $1.13           / 100g
# 38     $34.49          $4.51           / 100g
# 39      $4.00         $14.29           / 100g
# 40      $6.49          $2.04           / 100g
# 41     $21.99        $109.95          / 100ml
# 42     $11.49          $0.06            / 1ea
# 43     $10.11          $0.14            / 1ea
# 44     $11.99          $7.99          / 100ml
# 45      $9.99          $1.88          / 100ml
# 46      $7.99          $0.13            / 1ea
# 47     $44.99          $5.62            / 1ea
# 48      $6.99          $2.37          / 100ml
# 49     $14.99          $3.55           / 100g
# 50     $12.99          $0.43          / 100ml
# 51     $17.99         $17.99            / 1ea
# 52      $3.99          $2.00            / 1ea
# 53     $10.23            NaN              NaN
#
#                                      lowercase_Costco  \
# 0                                 salton glass kettle
# 1                      gillette fusion proglide power
# 2                         bio-oil skin care treatment
# 3              tide pods with downy laundry detergent
# 4                    tide he liquid laundry detergent
# 5                    lindt lindor assorted chocolates
# 6             webber naturals triple strength omega-3
# 7                                  jamieson probiotic
# 8        jamieson b100 complex timed-release vitamins
# 9                           samsung 75-in. television
# 10                  lorex 8 channel dvr camera system
# 11                                 details accent mat
# 12          starbucks caffè verona\nwhole-bean coffee
# 13  maple leaf natural selections sliced oven roas...
# 14     downy unstopables fresh\nin-wash scent booster
# 15                                glysomed hand cream
# 16  kirkland signature multivitamin and minerals f...
# 17                 sponge towels premium paper towels
# 18                                      puma backpack
# 19                    microsoft surface pro 7+ bundle
# 20            hp 14 in. touchscreen laptop, i5-1155g7
# 21                philips oneblade face & body shaver
# 22             van houtte original house blend coffee
# 23                folgers classic roast ground coffee
# 24                        nescafé rich instant coffee
# 25                                 no sugar keto bars
# 26                    jack link's teriyaki beef jerky
# 27                         clif builders protein bars
# 28                  crunchmaster multi-grain crackers
# 29                            kellogg’s vector cereal
# 30                    kellogg's frosted flakes cereal
# 31   san pellegrino naturali italian sparkling drinks
# 32                       splenda no calorie sweetener
# 33                      olive garden italian dressing
# 34                  beyond burger plant-based burgers
# 35                                     activia yogurt
# 36                         align probiotic supplement
# 37                kirkland signature omega-3 fish oil
# 38                                restoralax laxative
# 39  dove men + care clean comfort dry antiperspira...
# 40                   dove men + care extra fresh bars
# 41                      hydrasense eye drops advanced
# 42     jamieson calcium and magnesium with vitamin d3
# 43                          webber naturals melatonin
# 44          olay total effects nourishing moisturizer
# 45                     aveeno stress relief body wash
# 46                         g.u.m. soft-picks advanced
# 47                     gillette fusion proglide power
# 48                      vaseline cocoa radiant lotion
# 49      downy unstopables fresh in-wash scent booster
# 50               gain original liquid fabric softener
# 51                         swiffer dry or wet refills
# 52               mr. clean magic eraser cleaning pads
# 53                         cesar entrées wet dog food
#
#                                         lowercase_RCS  \
# 0                salton - 1.5 l cordless glass kettle
# 1                fusion proglide cartridges microcomb
# 2   argan queen argan oil for hair nails and skin ...
# 3   with downy, liquid laundry detergent pods, apr...
# 4   tide liquid laundry detergent, original, 80 lo...
# 5                 chocolate, lindor assorted truffles
# 6                            omega-3, triple strength
# 7                                 probiotic 5 billion
# 8                   b100 complex 100mg, timed release
# 9   mount-it mi-346l 17.3 in articulating full mot...
# 10      lorex wireless security system with 4 cameras
# 11  custom printed rugs dm 62 lambson moose intrud...
# 12  caffè verona capsules, ground coffee for nespr...
# 13     natural selections oven roasted chicken breast
# 14  downy unstopables in-wash scent booster beads,...
# 15                                         hand cream
# 16  thin & crispy vegetables, spinach and goat che...
# 17  swedish dishcloth cellulose sponge cloth reusa...
# 18                           puma style camo backpack
# 19     satechi type-c multimedia adapter (space grey)
# 20  hp elitebook x360 1040 g8 14" touchscreen 2 in...
# 21  philips - cordless electric face and body trim...
# 22       van houtte original house blend medium roast
# 23                        classic roast ground coffee
# 24  nescafé sweet and creamy original instant coff...
# 25                                  no sugar keto bar
# 26                               beef jerky, teriyaki
# 27     builders protein builder's bar, chocolate mint
# 28                   butter flavour microwave popcorn
# 29                     vector meal replacement cereal
# 30                                     fun pac cereal
# 31    naturali pompelmo sparkling grapefruit beverage
# 32                                           granular
# 33                                   italian dressing
# 34                          beyond burger plant-based
# 35  probiotic yogurt, strawberry/blueberry/raspber...
# 36             daily probiotic supplement, 50 gummies
# 37                                      eggs, omega-3
# 38  powder laxative, effective relief, no taste, n...
# 39    men+care dry spray antiperspirant cleancomfort
# 40  men+care body and face bar for refreshed skin ...
# 41  advanced eye drops, for dry eyes, preservative...
# 42                  calcium magnesium with vitamin d3
# 43                   melatonin 10mg, maximum strength
# 44  total effects nourishing cream cleanser face w...
# 45                            stress relief body wash
# 46                  soft-picks advanced dental picks
# 47               fusion proglide cartridges microcomb
# 48       men intensive care body lotion cocoa radiant
# 49      unstopable in-wash scent booster beads, fresh
# 50  fabric softener, original, 120 loads, he compa...
# 51  sweeper dry + wet sweeping kit 1 sweeper, 7 dr...
# 52                                       magic eraser
# 53       cesar® entrées filet mignon flavour 100g 1pc
#
#                                          no_sw_Costco  \
# 0                                 salton glass kettle
# 1                      gillette fusion proglide power
# 2                              bio-oil skin treatment
# 3                   tide pods downy laundry detergent
# 4                       tide liquid laundry detergent
# 5                    lindt lindor assorted chocolates
# 6             webber naturals triple strength omega-3
# 7                                  jamieson probiotic
# 8        jamieson b100 complex timed-release vitamins
# 9                          samsung 75-in . television
# 10                  lorex 8 channel dvr camera system
# 11                                     details accent
# 12           starbucks caffè verona whole-bean coffee
# 13   maple leaf natural selections sliced oven roa...
# 14      downy unstopables fresh in-wash scent booster
# 15                                glysomed hand cream
# 16     kirkland signature multivitamin minerals women
# 17                 sponge towels premium paper towels
# 18                                      puma backpack
# 19                    microsoft surface pro 7+ bundle
# 20             hp 14 . touchscreen laptop , i5-1155g7
# 21                     philips oneblade & body shaver
# 22                 houtte original house blend coffee
# 23                folgers classic roast ground coffee
# 24                        nescafé rich instant coffee
# 25                                    sugar keto bars
# 26                   jack link 's teriyaki beef jerky
# 27                         clif builders protein bars
# 28                  crunchmaster multi-grain crackers
# 29                            kellogg ’ vector cereal
# 30                   kellogg 's frosted flakes cereal
# 31   san pellegrino naturali italian sparkling drinks
# 32                          splenda calorie sweetener
# 33                      olive garden italian dressing
# 34                         burger plant-based burgers
# 35                                     activia yogurt
# 36                         align probiotic supplement
# 37                kirkland signature omega-3 fish oil
# 38                                restoralax laxative
# 39           + clean comfort dry antiperspirant spray
# 40                                 + extra fresh bars
# 41                      hydrasense eye drops advanced
# 42              jamieson calcium magnesium vitamin d3
# 43                          webber naturals melatonin
# 44          olay total effects nourishing moisturizer
# 45                     aveeno stress relief body wash
# 46                        g.u.m . soft-picks advanced
# 47                     gillette fusion proglide power
# 48                      vaseline cocoa radiant lotion
# 49      downy unstopables fresh in-wash scent booster
# 50                    original liquid fabric softener
# 51                            swiffer dry wet refills
# 52               mr. clean magic eraser cleaning pads
# 53                             cesar entrées wet food
#
#                                             no_sw_RCS
# 0                  salton - 1.5 cordless glass kettle
# 1                fusion proglide cartridges microcomb
# 2    argan queen argan oil hair nails skin 100 % b...
# 3    downy , liquid laundry detergent pods , april...
# 4    tide liquid laundry detergent , original , 80...
# 5                chocolate , lindor assorted truffles
# 6                           omega-3 , triple strength
# 7                                 probiotic 5 billion
# 8                  b100 complex 100mg , timed release
# 9    mount-it mi-346l 17.3 articulating full motio...
# 10           lorex wireless security system 4 cameras
# 11   custom printed rugs dm 62 lambson moose intru...
# 12   caffè verona capsules , ground coffee nespres...
# 13     natural selections oven roasted chicken breast
# 14   downy unstopables in-wash scent booster beads...
# 15                                         hand cream
# 16   thin & crispy vegetables , spinach goat chees...
# 17   swedish dishcloth cellulose sponge cloth reus...
# 18                           puma style camo backpack
# 19   satechi type-c multimedia adapter ( space grey )
# 20   hp elitebook x360 1040 g8 14 '' touchscreen 2...
# 21   philips - cordless electric body trimmer rech...
# 22           houtte original house blend medium roast
# 23                        classic roast ground coffee
# 24   nescafé sweet creamy original instant coffee mix
# 25                                     sugar keto bar
# 26                              beef jerky , teriyaki
# 27        builders protein builder 's bar , chocolate
# 28                   butter flavour microwave popcorn
# 29                     vector meal replacement cereal
# 30                                     fun pac cereal
# 31    naturali pompelmo sparkling grapefruit beverage
# 32                                           granular
# 33                                   italian dressing
# 34                                 burger plant-based
# 35   probiotic yogurt , strawberry/blueberry/raspb...
# 36            daily probiotic supplement , 50 gummies
# 37                                     eggs , omega-3
# 38   powder laxative , effective relief , taste , ...
# 39     men+care dry spray antiperspirant cleancomfort
# 40       men+care body bar refreshed skin extra fresh
# 41   advanced eye drops , dry eyes , preservative ...
# 42                       calcium magnesium vitamin d3
# 43                  melatonin 10mg , maximum strength
# 44   total effects nourishing cream cleanser wash ...
# 45                            stress relief body wash
# 46                   soft-picks advanced dental picks
# 47               fusion proglide cartridges microcomb
# 48                intensive body lotion cocoa radiant
# 49     unstopable in-wash scent booster beads , fresh
# 50   fabric softener , original , 120 loads , comp...
# 51   sweeper dry + wet sweeping kit 1 sweeper , 7 ...
# 52                                       magic eraser
# 53       cesar® entrées filet mignon flavour 100g 1pc

# %% [markdown]
# #### Sentence comparison
# Here we will look at the percentage of similarities in sentences for the same costco vs rcs item

# %%
# getting number of rows from dataframe
length = len(rcs_costco.index)

# creating empty lists to store the similarity of the sentences from both Costco and RCS items
lowercase_item_similarity = []
no_sw_item_similarity = []

# iterating through each row and comparing the "same" item from Costco and RCS
for i in range(length):
    lowercase_item_similarity.append(nlp(rcs_costco.iloc[i][7]).similarity(nlp(rcs_costco.iloc[i][8])))
    no_sw_item_similarity.append(nlp(rcs_costco.iloc[i][9]).similarity(nlp(rcs_costco.iloc[i][10])))

    
rcs_costco['lowercase_item_similarity'] = lowercase_item_similarity
rcs_costco['no_sw_item_similarity'] = no_sw_item_similarity
rcs_costco
# Out:
#                                           Costco-Item Costco-Price  \
# 0                                 Salton glass kettle      $34.99
# 1                      Gillette Fusion ProGlide Power      $49.99
# 2                         Bio-Oil skin care treatment      $19.99
# 3              Tide Pods with Downy laundry detergent      $20.99
# 4                    Tide HE liquid laundry detergent      $18.99
# 5                    Lindt Lindor assorted chocolates      $17.49
# 6             Webber Naturals triple strength Omega-3      $23.99
# 7                                  Jamieson probiotic      $23.99
# 8        Jamieson B100 complex timed-release vitamins      $20.99
# 9                           Samsung 75-in. television    $1,689.99
# 10                  Lorex 8 channel DVR camera system      $399.99
# 11                                 Details accent mat       $16.99
# 12          Starbucks Caffè Verona\nwhole-bean coffee       $17.99
# 13  Maple Leaf Natural Selections sliced oven roas...       $13.99
# 14     Downy Unstopables Fresh\nin-wash scent booster       $15.99
# 15                                Glysomed hand cream       $11.89
# 16  Kirkland Signature multivitamin and minerals f...       $15.99
# 17                 Sponge Towels Premium paper towels       $17.99
# 18                                      Puma backpack       $23.99
# 19                    Microsoft Surface Pro 7+ bundle      $999.99
# 20            HP 14 in. touchscreen laptop, i5-1155G7      $699.99
# 21                Philips OneBlade face & body shaver       $39.99
# 22             Van Houtte original house blend coffee       $33.99
# 23                Folgers classic roast ground coffee        $8.69
# 24                        Nescafé Rich instant coffee        $8.49
# 25                                 No sugar keto bars       $15.99
# 26                    Jack Link's teriyaki beef jerky       $11.49
# 27                         Clif Builders protein bars       $16.49
# 28                  Crunchmaster multi-grain crackers        $6.49
# 29                            Kellogg’s Vector cereal        $7.99
# 30                    Kellogg's Frosted Flakes cereal        $6.99
# 31   San Pellegrino Naturali Italian sparkling drinks       $14.99
# 32                       Splenda no calorie sweetener       $19.99
# 33                      Olive Garden Italian dressing        $7.99
# 34                  Beyond Burger plant-based burgers       $14.99
# 35                                     Activia yogurt        $7.49
# 36                         Align probiotic supplement       $39.99
# 37                Kirkland Signature omega-3 fish oil       $19.99
# 38                                RestoraLAX laxative       $30.99
# 39  Dove Men + Care Clean Comfort dry antiperspira...       $12.99
# 40                   Dove Men + Care Extra Fresh bars       $12.99
# 41                      Hydrasense eye drops advanced       $18.99
# 42     Jamieson calcium and magnesium with vitamin D3        $7.99
# 43                          Webber Naturals melatonin        $9.99
# 44          Olay Total Effects nourishing moisturizer       $28.99
# 45                     Aveeno stress relief body wash       $14.99
# 46                         G.U.M. Soft-Picks Advanced       $13.99
# 47                     Gillette Fusion ProGlide Power       $53.99
# 48                      Vaseline Cocoa Radiant lotion        $8.99
# 49      Downy Unstopables Fresh in-wash scent booster       $17.49
# 50               Gain original liquid fabric softener       $14.49
# 51                         Swiffer dry or wet refills       $15.99
# 52               Mr. Clean Magic Eraser cleaning pads        $9.99
# 53                         Cesar Entrées wet dog food       $29.59
#
#           RCS-Brand                                           RCS-Item  \
# 0               NaN               Salton - 1.5 L Cordless Glass Kettle
# 1          Gillette               Fusion Proglide Cartridges Microcomb
# 2               NaN  Argan Queen Argan Oil for Hair Nails and Skin ...
# 3              Tide  With Downy, Liquid Laundry Detergent Pods, Apr...
# 4              Tide  Tide Liquid Laundry Detergent, Original, 80 lo...
# 5             Lindt                Chocolate, Lindor Assorted Truffles
# 6   Webber Naturals                           Omega-3, Triple Strength
# 7          Jamieson                                Probiotic 5 Billion
# 8          Jamieson                  B100 Complex 100mg, Timed Release
# 9               NaN  Mount-It MI-346L 17.3 in Articulating Full Mot...
# 10              NaN      Lorex wireless security system with 4 cameras
# 11              NaN  Custom Printed Rugs DM 62 Lambson Moose Intrud...
# 12        Starbucks  Caffè Verona Capsules, Ground Coffee For Nespr...
# 13       Maple Leaf     Natural Selections Oven Roasted Chicken Breast
# 14            Downy  Downy Unstopables In-Wash Scent Booster Beads,...
# 15         Glysomed                                         Hand Cream
# 16     PC Blue Menu  Thin & Crispy Vegetables, Spinach And Goat Che...
# 17              NaN  Swedish Dishcloth Cellulose Sponge Cloth Reusa...
# 18              NaN                           Puma Style Camo Backpack
# 19              NaN     Satechi Type-C Multimedia Adapter (Space Grey)
# 20              NaN  HP EliteBook x360 1040 G8 14" Touchscreen 2 in...
# 21              NaN  Philips - Cordless Electric Face and Body Trim...
# 22           Keurig       Van Houtte Original House Blend Medium Roast
# 23          Folgers                        Classic Roast Ground Coffee
# 24          Nescafe  Nescafé Sweet and Creamy Original Instant Coff...
# 25       Vegan Pure                                  No Sugar Keto Bar
# 26       Jack Links                               Beef Jerky, Teriyaki
# 27             Clif     Builders Protein Builder's Bar, Chocolate Mint
# 28     PC Blue Menu                   Butter Flavour Microwave Popcorn
# 29         Kelloggs                     Vector Meal Replacement Cereal
# 30         Kelloggs                                     Fun Pac Cereal
# 31   San Pellegrino    Naturali Pompelmo Sparkling Grapefruit Beverage
# 32          Splenda                                           Granular
# 33     Olive Garden                                   Italian Dressing
# 34      Beyond Meat                          Beyond Burger Plant-Based
# 35          Activia  Probiotic Yogurt, Strawberry/Blueberry/Raspber...
# 36            Align             Daily Probiotic Supplement, 50 Gummies
# 37     PC Blue Menu                                      Eggs, Omega-3
# 38       Restoralax  Powder Laxative, Effective Relief, No Taste, N...
# 39             Dove    Men+Care Dry Spray Antiperspirant CleanComfort
# 40             Dove  Men+Care Body And Face Bar for Refreshed Skin ...
# 41       Hydrasense  Advanced Eye Drops, For Dry Eyes, Preservative...
# 42         Jamieson                  Calcium Magnesium with Vitamin D3
# 43  Webber Naturals                   Melatonin 10mg, Maximum Strength
# 44             Olay  Total Effects Nourishing Cream Cleanser Face W...
# 45           Aveeno                            Stress Relief Body Wash
# 46              Gum                  Soft-Picks Advanced Dental Picks
# 47         Gillette               Fusion Proglide Cartridges Microcomb
# 48         Vaseline       Men Intensive Care Body Lotion Cocoa Radiant
# 49            Downy      Unstopable In-Wash Scent Booster Beads, Fresh
# 50             Gain  Fabric Softener, Original, 120 Loads, He Compa...
# 51          Swiffer  Sweeper Dry + Wet Sweeping Kit 1 Sweeper, 7 Dr...
# 52        Mr. Clean                                       Magic Eraser
# 53              NaN       CESAR® ENTRÉES FILET MIGNON FLAVOUR 100g 1Pc
#
#     RCS-Price RCS-Unit Price RCS-Unit Measure  \
# 0      $62.33            NaN              NaN
# 1      $44.99          $5.62            / 1ea
# 2      $22.00            NaN              NaN
# 3      $23.99          $1.51           / 100g
# 4      $19.99          $0.59          / 100ml
# 5       $9.99          $4.16           / 100g
# 6      $16.11          $0.20            / 1ea
# 7      $16.49          $0.23            / 1ea
# 8      $22.99          $0.19            / 1ea
# 9     $200.37            NaN              NaN
# 10    $274.99            NaN              NaN
# 11     $25.37            NaN              NaN
# 12      $9.99          $9.99           / 100g
# 13      $6.49         $37.09            / 1kg
# 14      $9.99          $3.51           / 100g
# 15      $6.99          $4.66          / 100ml
# 16      $3.29          $0.91           / 100g
# 17      $9.99            NaN              NaN
# 18     $39.25            NaN              NaN
# 19    $156.19            NaN              NaN
# 20  $2,786.06            NaN              NaN
# 21     $99.97            NaN              NaN
# 22     $10.99          $0.92            / 1ea
# 23      $7.99          $0.87           / 100g
# 24      $7.49          $2.13           / 100g
# 25     $11.99          $7.49           / 100g
# 26      $6.99          $8.74           / 100g
# 27      $2.19          $3.22           / 100g
# 28      $4.29          $0.89           / 100g
# 29      $9.49          $1.12           / 100g
# 30      $5.49          $2.61           / 100g
# 31      $5.99          $0.30          / 100ml
# 32      $6.29          $5.72           / 100g
# 33      $4.89          $1.03          / 100ml
# 34      $7.49          $3.31           / 100g
# 35      $5.99          $0.50           / 100g
# 36     $24.49          $0.49            / 1ea
# 37      $0.99          $1.13           / 100g
# 38     $34.49          $4.51           / 100g
# 39      $4.00         $14.29           / 100g
# 40      $6.49          $2.04           / 100g
# 41     $21.99        $109.95          / 100ml
# 42     $11.49          $0.06            / 1ea
# 43     $10.11          $0.14            / 1ea
# 44     $11.99          $7.99          / 100ml
# 45      $9.99          $1.88          / 100ml
# 46      $7.99          $0.13            / 1ea
# 47     $44.99          $5.62            / 1ea
# 48      $6.99          $2.37          / 100ml
# 49     $14.99          $3.55           / 100g
# 50     $12.99          $0.43          / 100ml
# 51     $17.99         $17.99            / 1ea
# 52      $3.99          $2.00            / 1ea
# 53     $10.23            NaN              NaN
#
#                                      lowercase_Costco  \
# 0                                 salton glass kettle
# 1                      gillette fusion proglide power
# 2                         bio-oil skin care treatment
# 3              tide pods with downy laundry detergent
# 4                    tide he liquid laundry detergent
# 5                    lindt lindor assorted chocolates
# 6             webber naturals triple strength omega-3
# 7                                  jamieson probiotic
# 8        jamieson b100 complex timed-release vitamins
# 9                           samsung 75-in. television
# 10                  lorex 8 channel dvr camera system
# 11                                 details accent mat
# 12          starbucks caffè verona\nwhole-bean coffee
# 13  maple leaf natural selections sliced oven roas...
# 14     downy unstopables fresh\nin-wash scent booster
# 15                                glysomed hand cream
# 16  kirkland signature multivitamin and minerals f...
# 17                 sponge towels premium paper towels
# 18                                      puma backpack
# 19                    microsoft surface pro 7+ bundle
# 20            hp 14 in. touchscreen laptop, i5-1155g7
# 21                philips oneblade face & body shaver
# 22             van houtte original house blend coffee
# 23                folgers classic roast ground coffee
# 24                        nescafé rich instant coffee
# 25                                 no sugar keto bars
# 26                    jack link's teriyaki beef jerky
# 27                         clif builders protein bars
# 28                  crunchmaster multi-grain crackers
# 29                            kellogg’s vector cereal
# 30                    kellogg's frosted flakes cereal
# 31   san pellegrino naturali italian sparkling drinks
# 32                       splenda no calorie sweetener
# 33                      olive garden italian dressing
# 34                  beyond burger plant-based burgers
# 35                                     activia yogurt
# 36                         align probiotic supplement
# 37                kirkland signature omega-3 fish oil
# 38                                restoralax laxative
# 39  dove men + care clean comfort dry antiperspira...
# 40                   dove men + care extra fresh bars
# 41                      hydrasense eye drops advanced
# 42     jamieson calcium and magnesium with vitamin d3
# 43                          webber naturals melatonin
# 44          olay total effects nourishing moisturizer
# 45                     aveeno stress relief body wash
# 46                         g.u.m. soft-picks advanced
# 47                     gillette fusion proglide power
# 48                      vaseline cocoa radiant lotion
# 49      downy unstopables fresh in-wash scent booster
# 50               gain original liquid fabric softener
# 51                         swiffer dry or wet refills
# 52               mr. clean magic eraser cleaning pads
# 53                         cesar entrées wet dog food
#
#                                         lowercase_RCS  \
# 0                salton - 1.5 l cordless glass kettle
# 1                fusion proglide cartridges microcomb
# 2   argan queen argan oil for hair nails and skin ...
# 3   with downy, liquid laundry detergent pods, apr...
# 4   tide liquid laundry detergent, original, 80 lo...
# 5                 chocolate, lindor assorted truffles
# 6                            omega-3, triple strength
# 7                                 probiotic 5 billion
# 8                   b100 complex 100mg, timed release
# 9   mount-it mi-346l 17.3 in articulating full mot...
# 10      lorex wireless security system with 4 cameras
# 11  custom printed rugs dm 62 lambson moose intrud...
# 12  caffè verona capsules, ground coffee for nespr...
# 13     natural selections oven roasted chicken breast
# 14  downy unstopables in-wash scent booster beads,...
# 15                                         hand cream
# 16  thin & crispy vegetables, spinach and goat che...
# 17  swedish dishcloth cellulose sponge cloth reusa...
# 18                           puma style camo backpack
# 19     satechi type-c multimedia adapter (space grey)
# 20  hp elitebook x360 1040 g8 14" touchscreen 2 in...
# 21  philips - cordless electric face and body trim...
# 22       van houtte original house blend medium roast
# 23                        classic roast ground coffee
# 24  nescafé sweet and creamy original instant coff...
# 25                                  no sugar keto bar
# 26                               beef jerky, teriyaki
# 27     builders protein builder's bar, chocolate mint
# 28                   butter flavour microwave popcorn
# 29                     vector meal replacement cereal
# 30                                     fun pac cereal
# 31    naturali pompelmo sparkling grapefruit beverage
# 32                                           granular
# 33                                   italian dressing
# 34                          beyond burger plant-based
# 35  probiotic yogurt, strawberry/blueberry/raspber...
# 36             daily probiotic supplement, 50 gummies
# 37                                      eggs, omega-3
# 38  powder laxative, effective relief, no taste, n...
# 39    men+care dry spray antiperspirant cleancomfort
# 40  men+care body and face bar for refreshed skin ...
# 41  advanced eye drops, for dry eyes, preservative...
# 42                  calcium magnesium with vitamin d3
# 43                   melatonin 10mg, maximum strength
# 44  total effects nourishing cream cleanser face w...
# 45                            stress relief body wash
# 46                  soft-picks advanced dental picks
# 47               fusion proglide cartridges microcomb
# 48       men intensive care body lotion cocoa radiant
# 49      unstopable in-wash scent booster beads, fresh
# 50  fabric softener, original, 120 loads, he compa...
# 51  sweeper dry + wet sweeping kit 1 sweeper, 7 dr...
# 52                                       magic eraser
# 53       cesar® entrées filet mignon flavour 100g 1pc
#
#                                          no_sw_Costco  \
# 0                                 salton glass kettle
# 1                      gillette fusion proglide power
# 2                              bio-oil skin treatment
# 3                   tide pods downy laundry detergent
# 4                       tide liquid laundry detergent
# 5                    lindt lindor assorted chocolates
# 6             webber naturals triple strength omega-3
# 7                                  jamieson probiotic
# 8        jamieson b100 complex timed-release vitamins
# 9                          samsung 75-in . television
# 10                  lorex 8 channel dvr camera system
# 11                                     details accent
# 12           starbucks caffè verona whole-bean coffee
# 13   maple leaf natural selections sliced oven roa...
# 14      downy unstopables fresh in-wash scent booster
# 15                                glysomed hand cream
# 16     kirkland signature multivitamin minerals women
# 17                 sponge towels premium paper towels
# 18                                      puma backpack
# 19                    microsoft surface pro 7+ bundle
# 20             hp 14 . touchscreen laptop , i5-1155g7
# 21                     philips oneblade & body shaver
# 22                 houtte original house blend coffee
# 23                folgers classic roast ground coffee
# 24                        nescafé rich instant coffee
# 25                                    sugar keto bars
# 26                   jack link 's teriyaki beef jerky
# 27                         clif builders protein bars
# 28                  crunchmaster multi-grain crackers
# 29                            kellogg ’ vector cereal
# 30                   kellogg 's frosted flakes cereal
# 31   san pellegrino naturali italian sparkling drinks
# 32                          splenda calorie sweetener
# 33                      olive garden italian dressing
# 34                         burger plant-based burgers
# 35                                     activia yogurt
# 36                         align probiotic supplement
# 37                kirkland signature omega-3 fish oil
# 38                                restoralax laxative
# 39           + clean comfort dry antiperspirant spray
# 40                                 + extra fresh bars
# 41                      hydrasense eye drops advanced
# 42              jamieson calcium magnesium vitamin d3
# 43                          webber naturals melatonin
# 44          olay total effects nourishing moisturizer
# 45                     aveeno stress relief body wash
# 46                        g.u.m . soft-picks advanced
# 47                     gillette fusion proglide power
# 48                      vaseline cocoa radiant lotion
# 49      downy unstopables fresh in-wash scent booster
# 50                    original liquid fabric softener
# 51                            swiffer dry wet refills
# 52               mr. clean magic eraser cleaning pads
# 53                             cesar entrées wet food
#
#                                             no_sw_RCS  \
# 0                  salton - 1.5 cordless glass kettle
# 1                fusion proglide cartridges microcomb
# 2    argan queen argan oil hair nails skin 100 % b...
# 3    downy , liquid laundry detergent pods , april...
# 4    tide liquid laundry detergent , original , 80...
# 5                chocolate , lindor assorted truffles
# 6                           omega-3 , triple strength
# 7                                 probiotic 5 billion
# 8                  b100 complex 100mg , timed release
# 9    mount-it mi-346l 17.3 articulating full motio...
# 10           lorex wireless security system 4 cameras
# 11   custom printed rugs dm 62 lambson moose intru...
# 12   caffè verona capsules , ground coffee nespres...
# 13     natural selections oven roasted chicken breast
# 14   downy unstopables in-wash scent booster beads...
# 15                                         hand cream
# 16   thin & crispy vegetables , spinach goat chees...
# 17   swedish dishcloth cellulose sponge cloth reus...
# 18                           puma style camo backpack
# 19   satechi type-c multimedia adapter ( space grey )
# 20   hp elitebook x360 1040 g8 14 '' touchscreen 2...
# 21   philips - cordless electric body trimmer rech...
# 22           houtte original house blend medium roast
# 23                        classic roast ground coffee
# 24   nescafé sweet creamy original instant coffee mix
# 25                                     sugar keto bar
# 26                              beef jerky , teriyaki
# 27        builders protein builder 's bar , chocolate
# 28                   butter flavour microwave popcorn
# 29                     vector meal replacement cereal
# 30                                     fun pac cereal
# 31    naturali pompelmo sparkling grapefruit beverage
# 32                                           granular
# 33                                   italian dressing
# 34                                 burger plant-based
# 35   probiotic yogurt , strawberry/blueberry/raspb...
# 36            daily probiotic supplement , 50 gummies
# 37                                     eggs , omega-3
# 38   powder laxative , effective relief , taste , ...
# 39     men+care dry spray antiperspirant cleancomfort
# 40       men+care body bar refreshed skin extra fresh
# 41   advanced eye drops , dry eyes , preservative ...
# 42                       calcium magnesium vitamin d3
# 43                  melatonin 10mg , maximum strength
# 44   total effects nourishing cream cleanser wash ...
# 45                            stress relief body wash
# 46                   soft-picks advanced dental picks
# 47               fusion proglide cartridges microcomb
# 48                intensive body lotion cocoa radiant
# 49     unstopable in-wash scent booster beads , fresh
# 50   fabric softener , original , 120 loads , comp...
# 51   sweeper dry + wet sweeping kit 1 sweeper , 7 ...
# 52                                       magic eraser
# 53       cesar® entrées filet mignon flavour 100g 1pc
#
#     lowercase_item_similarity  no_sw_item_similarity
# 0                    0.633440               0.680754
# 1                    0.760436               0.760436
# 2                    0.692873               0.719365
# 3                    0.696956               0.542354
# 4                    0.677052               0.574008
# 5                    0.817858               0.817858
# 6                    0.824986               0.824986
# 7                    0.259369               0.259369
# 8                    0.627782               0.627782
# 9                    0.642309               0.460978
# 10                   0.842792               0.884882
# 11                   0.514020               0.481948
# 12                   0.599296               0.659731
# 13                   0.935073               0.935073
# 14                   0.959881               0.959881
# 15                   1.000000               1.000000
# 16                   0.420620               0.358214
# 17                   0.664617               0.674448
# 18                   0.742105               0.742105
# 19                   0.440716               0.440716
# 20                   0.689105               0.720364
# 21                   0.525966               0.368981
# 22                   0.929824               0.899108
# 23                   0.993523               0.993523
# 24                   0.804843               0.805665
# 25                   0.957858               0.903783
# 26                   0.587382               0.587382
# 27                   0.713576               0.717702
# 28                   0.434144               0.434144
# 29                   0.423856               0.378273
# 30                   0.358513               0.358513
# 31                   0.719025               0.719025
# 32                   0.269683               0.345901
# 33                   0.813844               0.813844
# 34                   0.982629               0.980355
# 35                   0.327386               0.327386
# 36                   0.588033               0.588033
# 37                   0.583483               0.583483
# 38                   0.555538               0.699498
# 39                   0.675441               0.773497
# 40                   0.559962               0.506863
# 41                   0.721671               0.757146
# 42                   0.950927               1.000000
# 43                   0.385882               0.385882
# 44                   0.777516               0.779767
# 45                   0.998016               0.998016
# 46                   0.900997               0.900997
# 47                   0.760436               0.760436
# 48                   0.737562               0.883779
# 49                   0.952704               0.952704
# 50                   0.575183               0.636248
# 51                   0.596606               0.689004
# 52                   0.599857               0.599856
# 53                   0.279625               0.321679

# %% [markdown]
# ### Plot distribution of sentence similarity
# Here we will be looking at the distribution of the item similarity.
# We want to do this to see which model has the highest similarity between the sentences analyzed.
#
# **Our four models are:**
# 1) Branded lowercase RCS vs Costco items
# 2) Branded lowercase no stopwords RCS vs Costco items
# 3) Non-Branded (stripped) lowercase RCS vs Costco items
# 4) Non-Branded (stripped) lowercase no stopwords RCS vs Costco items

# %%
# Plot the distribution of our four models listed above
fig, axes = plt.subplots(2, 2, figsize=(25,10))
sns.histplot(x=rcs_costco['lowercase_item_similarity'], kde=True, ax=axes[0,0]);
axes[0,0].set(xlabel='Branded Lowercase Item Similarity');

sns.histplot(x=stripped_rcs_costco['lowercase_item_similarity'], kde=True, ax=axes[0,1]);
axes[0,1].set(xlabel='Non-Branded Lowercase Item Similarity');

sns.histplot(x=rcs_costco['no_sw_item_similarity'], kde=True, ax=axes[1,0]);
axes[1,0].set(xlabel='Branded Lowercase No Stopwords Item Similarity');

sns.histplot(x=stripped_rcs_costco['no_sw_item_similarity'], kde=True, ax=axes[1,1]);
axes[1,1].set(xlabel='Non-Branded Lowercase No Stopwords Item Similarity');

# %% [markdown]
# Based on these distributions, it would seem that the "non-branded" data is more accurate especially when looking at the case where stopwords have been removed.
#
# However, we must think about the fact that we just compared sentences and not whether or not they are an actual match because we do not know the ground truth. Therefore, we must go back and enter whether there is a match (1) or not (0) and compare which model best predicted a match.

# %% [markdown]
# ## Comparing Matches

# %% [markdown]
# Here we will compare all 4 models to the ground truth to see which model had the best predictability.

# %% [markdown]
# First, extract dfs to CSV to create column of match (1) vs no match (0).
#
# Rules for whether match (1) or not (0), must be same brand and product unless "Kirkland" specific then "President Choice" brand is accepted. Reason for this is because both are only specific to their companies so they should be selling at approximately the same price ("house" price).

# %%
rcs_costco.to_csv('/Users/anjawu/Code/RCS/rcs_costco_df.csv')
stripped_rcs_costco.to_csv('/Users/anjawu/Code/RCS/stripped_rcs_costco_df.csv')

# %% [markdown]
# Import new CSVs with ground truth about whether entries from two stores are matches:

# %%
rcs_costco_df_matches = pd.read_csv('/Users/anjawu/Code/RCS/rcs_costco_df_matches.csv')
stripped_rcs_costco_df_matches = pd.read_csv('/Users/anjawu/Code/RCS/stripped_rcs_costco_df_matches.csv')

# %% [markdown]
# Compare amount of matching values:

# %%
rcs_costco_df_matches['matches'].value_counts(normalize=True)
# Out:
# 1    0.814815
# 0    0.185185
# Name: matches, dtype: float64

# %%
stripped_rcs_costco_df_matches['matches'].value_counts(normalize=True)
# Out:
# 0    0.603774
# 1    0.396226
# Name: matches, dtype: float64

# %% [markdown]
# As can be seen, the branded search gives us a significantly higher percentage of correct matches (81%) compared to the non-branded search (40%). As a reminder the branded one returns a bit under twice less than the non-branded one (54 items versus 106 items), but is a bit more than twice better in getting correct matches.

# %% [markdown]
# # Run t-test to see if there is statistically significant difference in accuracy of matches. p1 = 0.81, p2 = 0.4, n1 = 54, n2 = 106. Check conditions of t-test to see if valid to run it.

# %% [markdown]
# #### From the previous analysis we can conclude that the best model for matches is branded! So we will create a dataframe that contains just the matched (1) items for both RCS and Costco (matched_rcs_costco)! This is the one we will be using to compare prices between the two stores.

# %% [markdown]
# ### Removing incorrect hits
# Here we will remove the rows that were not matches from our best model (found in previous step)

# %%
matched_rcs_costco = rcs_costco_df_matches[rcs_costco_df_matches['matches']==1].reset_index()
matched_rcs_costco = matched_rcs_costco.drop(columns=['Unnamed: 0','index'])

not_matched_rcs_costco = rcs_costco_df_matches[rcs_costco_df_matches['matches']==0].reset_index()
not_matched_rcs_costco = not_matched_rcs_costco.drop(columns=['Unnamed: 0','index'])

# %% [markdown]
# Look at the distribution of percentages of sentence similarities based on matches vs no match, due to curiosity.

# %%
fig, axes = plt.subplots(2, 2, figsize=(25,10))

sns.histplot(x=matched_rcs_costco['lowercase_item_similarity'], kde=True, ax=axes[0,0]);
axes[0,0].set(xlabel='Matched Branded Lowercase Item Similarity');

sns.histplot(x=matched_rcs_costco['no_sw_item_similarity'], kde=True, ax=axes[0,1]);
axes[0,1].set(xlabel='Matched Branded No Stop Words Item Similarity');

sns.histplot(x=not_matched_rcs_costco['lowercase_item_similarity'], kde=True, ax=axes[1,0]);
axes[1,0].set(xlabel='Not Matched Branded Lowercase Item Similarity');

sns.histplot(x=not_matched_rcs_costco['no_sw_item_similarity'], kde=True, ax=axes[1,1]);
axes[1,1].set(xlabel='Not Matched Branded No Stop Words Item Similarity');

# %% [markdown]
# The data shows that there is a larger range for matched item similarity (below 0.3 all the way to 1.0), with and without stop words. This implies that there is not much of a point for searching on the Real Canadian Superstore with either of these methods as it does not yield consistent results.

# %% [markdown]
# ----

# %% [markdown]
# ## Comparing prices for Costco and Real-Canadian Superstore

# %% [markdown]
# Now that we have looked at which model gives us the most accurate and largest set and we have filtered out only the matches, we can now compare the prices from the two stores to see which one is a better deal.

# %% [markdown]
# 1) Look at number of prices for Costco that are lower than RCS
# 2) Find percentage of prices that are lower
# 3) Look at distribution of prices for (double bar graph) to see spread of two company differences
# 4) Can I quantify the numerical difference in prices in a meaningful way to show the difference between the two companies? Maybe do mean spread of data difference.

# %% [markdown]
# Change the formating of the price columns to be float:

# %%
# range of both the RCS and Costco prices will be the same 
range_list = len(matched_rcs_costco)

# create lists to store the float (converted string without "$")
new_rcs_price_flt = []
new_costco_price_flt = []

# cycle through the two columns for both the RCS and Costco prices to remove "$" and convert to float
for i in range(range_list):
     new_rcs_price_flt.append(float(matched_rcs_costco['RCS-Price'][i].lstrip('$')))
     new_costco_price_flt.append(float(matched_rcs_costco['Costco-Price'][i].lstrip('$')))
        
# create new columns to store the new form of value
matched_rcs_costco['RCS-Price_flt'] = new_rcs_price_flt
matched_rcs_costco['Costco-Price_flt'] = new_costco_price_flt

# %% [markdown]
# We look at the number values where Costco's prices are lower:

# %%
matched_rcs_costco['RCS-Price_flt'].index
# Out:
# RangeIndex(start=0, stop=44, step=1)

# %%
rcs_column = matched_rcs_costco['RCS-Price_flt']
costco_column = matched_rcs_costco['Costco-Price_flt']

# Get count of items where Costco was cheaper than RCS:
costco_column[costco_column < rcs_column].count()
# Out:
# 12

# %%
rcs_column = matched_rcs_costco['RCS-Price_flt']
costco_column = matched_rcs_costco['Costco-Price_flt']

# Get count of values greater than 20 in the column 'C' 
rcs_column[costco_column >= rcs_column].count()
# Out:
# 32

# %% [markdown]
# *This means out of 44 items only 12 of them are cheaper at Costco*

# %% [markdown]
# ### This seemed odd to me, so I went and analyzed the matches and I noticed one thing right away. RCS is really great because it lists the products by comparing the unit price, however, Costco has no indication how much you are really getting for the price - unless you look at the photo of the product.

# %% [markdown]
# I decided to export the matches I have and look up the 44 individual Costco products (which need unit prices) and enter a new column that includes this.

# %%
# export current matches to csv to create 2 columns for rcs and costco unit for each item 
# (based on looking at Costco's website and the scraped amounts for rcs)
matched_rcs_costco.to_csv('/Users/anjawu/Code/RCS/matched_rcs_costco_unitprice.csv')

# %%
# save editted CSV to dataframe and clean up the unnecessary columns to create a concise new dataframe
matched_rcs_costco_unitprice = pd.read_csv('/Users/anjawu/Code/RCS/matched_rcs_costco_units.csv')
matched_rcs_costco_unitprice = matched_rcs_costco_unitprice.reset_index()
matched_rcs_costco_unitprice = matched_rcs_costco_unitprice.drop(columns=['Unnamed: 0','index'])

shortened_matched_rcs_costco_unitprice = matched_rcs_costco_unitprice.drop(columns=['Costco-Price','RCS-Price','RCS-Unit Price','RCS-Unit Measure','lowercase_Costco','lowercase_RCS','no_sw_Costco','no_sw_RCS','lowercase_item_similarity','no_sw_item_similarity','matches'])
# shortened_matched_rcs_costco_unitprice

# %%
unit_price_rcs = []
unit_price_costco = []

# create for loop to calculate the unit price for each item; be sure to check for NaN - if yes then just use price in "Price_flt" column:
for i in range(len(shortened_matched_rcs_costco_unitprice)):
    # if both the costco and rcs have values then calculate the unit price based on price and units given
    if (math.isnan(shortened_matched_rcs_costco_unitprice['costco_amount'][i]) == False) and (math.isnan(shortened_matched_rcs_costco_unitprice['rcs_amount'][i]) == False):
        rcs_unit_price = shortened_matched_rcs_costco_unitprice['RCS-Price_flt'][i]/shortened_matched_rcs_costco_unitprice['rcs_amount'][i]
        costco_unit_price = shortened_matched_rcs_costco_unitprice['Costco-Price_flt'][i]/shortened_matched_rcs_costco_unitprice['costco_amount'][i]
        
        unit_price_rcs.append(rcs_unit_price)
        unit_price_costco.append(costco_unit_price)
#         print(f'{i}) rcs is not NaN: {rcs_unit_price}, costco is not Nan: {costco_unit_price}')
        
    else:
        # if costco OR rcs are NaN for their units then take the whole price given from the websites for BOTH stores
        rcs_unit_price_null = shortened_matched_rcs_costco_unitprice['RCS-Price_flt'][i]
        costco_unit_price_null = shortened_matched_rcs_costco_unitprice['Costco-Price_flt'][i]
        
        unit_price_rcs.append(rcs_unit_price_null)
        unit_price_costco.append(costco_unit_price_null)
#         print(f'{i}) rcs: {rcs_unit_price_null}, costco: {costco_unit_price_null}')
    
# create columns to store the unit prices per store
shortened_matched_rcs_costco_unitprice['RCS_unit_price'] = unit_price_rcs
shortened_matched_rcs_costco_unitprice['Costco_unit_price'] = unit_price_costco

shortened_matched_rcs_costco_unitprice
# Out:
#                                           Costco-Item        RCS-Brand  \
# 0                                 Salton glass kettle              NaN
# 1                      Gillette Fusion ProGlide Power         Gillette
# 2              Tide Pods with Downy laundry detergent             Tide
# 3                    Tide HE liquid laundry detergent             Tide
# 4                    Lindt Lindor assorted chocolates            Lindt
# 5             Webber Naturals triple strength Omega-3  Webber Naturals
# 6                                  Jamieson probiotic         Jamieson
# 7        Jamieson B100 complex timed-release vitamins         Jamieson
# 8                   Lorex 8 channel DVR camera system              NaN
# 9           Starbucks Caffè Verona\nwhole-bean coffee        Starbucks
# 10  Maple Leaf Natural Selections sliced oven roas...       Maple Leaf
# 11     Downy Unstopables Fresh\nin-wash scent booster            Downy
# 12                                Glysomed hand cream         Glysomed
# 13                                      Puma backpack              NaN
# 14                Philips OneBlade face & body shaver              NaN
# 15             Van Houtte original house blend coffee           Keurig
# 16                Folgers classic roast ground coffee          Folgers
# 17                        Nescafé Rich instant coffee          Nescafe
# 18                                 No sugar keto bars       Vegan Pure
# 19                    Jack Link's teriyaki beef jerky       Jack Links
# 20                         Clif Builders protein bars             Clif
# 21                            Kellogg’s Vector cereal         Kelloggs
# 22   San Pellegrino Naturali Italian sparkling drinks   San Pellegrino
# 23                       Splenda no calorie sweetener          Splenda
# 24                      Olive Garden Italian dressing     Olive Garden
# 25                  Beyond Burger plant-based burgers      Beyond Meat
# 26                                     Activia yogurt          Activia
# 27                         Align probiotic supplement            Align
# 28                                RestoraLAX laxative       Restoralax
# 29  Dove Men + Care Clean Comfort dry antiperspira...             Dove
# 30                   Dove Men + Care Extra Fresh bars             Dove
# 31                      Hydrasense eye drops advanced       Hydrasense
# 32     Jamieson calcium and magnesium with vitamin D3         Jamieson
# 33                          Webber Naturals melatonin  Webber Naturals
# 34          Olay Total Effects nourishing moisturizer             Olay
# 35                     Aveeno stress relief body wash           Aveeno
# 36                         G.U.M. Soft-Picks Advanced              Gum
# 37                     Gillette Fusion ProGlide Power         Gillette
# 38                      Vaseline Cocoa Radiant lotion         Vaseline
# 39      Downy Unstopables Fresh in-wash scent booster            Downy
# 40               Gain original liquid fabric softener             Gain
# 41                         Swiffer dry or wet refills          Swiffer
# 42               Mr. Clean Magic Eraser cleaning pads        Mr. Clean
# 43                         Cesar Entrées wet dog food              NaN
#
#                                              RCS-Item  RCS-Price_flt  \
# 0                Salton - 1.5 L Cordless Glass Kettle          62.33
# 1                Fusion Proglide Cartridges Microcomb          44.99
# 2   With Downy, Liquid Laundry Detergent Pods, Apr...          23.99
# 3   Tide Liquid Laundry Detergent, Original, 80 lo...          19.99
# 4                 Chocolate, Lindor Assorted Truffles           9.99
# 5                            Omega-3, Triple Strength          16.11
# 6                                 Probiotic 5 Billion          16.49
# 7                   B100 Complex 100mg, Timed Release          22.99
# 8       Lorex wireless security system with 4 cameras         274.99
# 9   Caffè Verona Capsules, Ground Coffee For Nespr...           9.99
# 10     Natural Selections Oven Roasted Chicken Breast           6.49
# 11  Downy Unstopables In-Wash Scent Booster Beads,...           9.99
# 12                                         Hand Cream           6.99
# 13                           Puma Style Camo Backpack          39.25
# 14  Philips - Cordless Electric Face and Body Trim...          99.97
# 15       Van Houtte Original House Blend Medium Roast          10.99
# 16                        Classic Roast Ground Coffee           7.99
# 17  Nescafé Sweet and Creamy Original Instant Coff...           7.49
# 18                                  No Sugar Keto Bar          11.99
# 19                               Beef Jerky, Teriyaki           6.99
# 20     Builders Protein Builder's Bar, Chocolate Mint           2.19
# 21                     Vector Meal Replacement Cereal           9.49
# 22    Naturali Pompelmo Sparkling Grapefruit Beverage           5.99
# 23                                           Granular           6.29
# 24                                   Italian Dressing           4.89
# 25                          Beyond Burger Plant-Based           7.49
# 26  Probiotic Yogurt, Strawberry/Blueberry/Raspber...           5.99
# 27             Daily Probiotic Supplement, 50 Gummies          24.49
# 28  Powder Laxative, Effective Relief, No Taste, N...          34.49
# 29    Men+Care Dry Spray Antiperspirant CleanComfort            4.00
# 30  Men+Care Body And Face Bar for Refreshed Skin ...           6.49
# 31  Advanced Eye Drops, For Dry Eyes, Preservative...          21.99
# 32                  Calcium Magnesium with Vitamin D3          11.49
# 33                   Melatonin 10mg, Maximum Strength          10.11
# 34  Total Effects Nourishing Cream Cleanser Face W...          11.99
# 35                            Stress Relief Body Wash           9.99
# 36                  Soft-Picks Advanced Dental Picks            7.99
# 37               Fusion Proglide Cartridges Microcomb          44.99
# 38       Men Intensive Care Body Lotion Cocoa Radiant           6.99
# 39      Unstopable In-Wash Scent Booster Beads, Fresh          14.99
# 40  Fabric Softener, Original, 120 Loads, He Compa...          12.99
# 41  Sweeper Dry + Wet Sweeping Kit 1 Sweeper, 7 Dr...          17.99
# 42                                       Magic Eraser           3.99
# 43       CESAR® ENTRÉES FILET MIGNON FLAVOUR 100g 1Pc          10.23
#
#     rcs_amount  Costco-Price_flt  costco_amount  RCS_unit_price  \
# 0          NaN             34.99            NaN       62.330000
# 1          NaN             49.99            NaN       44.990000
# 2         61.0             20.99          104.0        0.393279
# 3       3388.0             18.99         4870.0        0.005900
# 4        240.0             17.49          900.0        0.041625
# 5         81.0             23.99          200.0        0.198889
# 6         72.0             23.99          135.0        0.229028
# 7        121.0             20.99          200.0        0.190000
# 8          NaN            399.99            NaN      274.990000
# 9        100.0             17.99         1130.0        0.099900
# 10         NaN             13.99            NaN        6.490000
# 11       285.0             15.99         1060.0        0.035053
# 12       150.0             11.89          550.0        0.046600
# 13         NaN             23.99            NaN       39.250000
# 14         NaN             39.99            NaN       99.970000
# 15        12.0             33.99           80.0        0.915833
# 16       918.0              8.69         1120.0        0.008704
# 17       352.0              8.49          475.0        0.021278
# 18       160.0             15.99          480.0        0.074938
# 19        80.0             11.49          300.0        0.087375
# 20        68.0             16.49         1224.0        0.032206
# 21       847.0              7.99         1130.0        0.011204
# 22      1997.0             14.99         7920.0        0.002999
# 23       110.0             19.99          715.0        0.057182
# 24       475.0              7.99            NaN        4.890000
# 25       226.0             14.99          678.0        0.033142
# 26      1198.0              7.49            NaN        5.990000
# 27        50.0             39.99           63.0        0.489800
# 28       765.0             30.99         1224.0        0.045085
# 29        28.0             12.99          380.0        0.142857
# 30       318.0             12.99         1696.0        0.020409
# 31        20.0             18.99           30.0        1.099500
# 32       192.0              7.99          420.0        0.059844
# 33        72.0              9.99          300.0        0.140417
# 34       150.0             28.99            NaN       11.990000
# 35       531.0             14.99         1596.0        0.018814
# 36        61.0             13.99          270.0        0.130984
# 37         8.0             53.99           18.0        5.623750
# 38       295.0              8.99         1495.0        0.023695
# 39       422.0             17.49         1060.0        0.035521
# 40      3021.0             14.49         5030.0        0.004300
# 41         NaN             15.99            NaN       17.990000
# 42         2.0              9.99            9.0        1.995000
# 43         NaN             29.59            NaN       10.230000
#
#     Costco_unit_price
# 0           34.990000
# 1           49.990000
# 2            0.201827
# 3            0.003899
# 4            0.019433
# 5            0.119950
# 6            0.177704
# 7            0.104950
# 8          399.990000
# 9            0.015920
# 10          13.990000
# 11           0.015085
# 12           0.021618
# 13          23.990000
# 14          39.990000
# 15           0.424875
# 16           0.007759
# 17           0.017874
# 18           0.033313
# 19           0.038300
# 20           0.013472
# 21           0.007071
# 22           0.001893
# 23           0.027958
# 24           7.990000
# 25           0.022109
# 26           7.490000
# 27           0.634762
# 28           0.025319
# 29           0.034184
# 30           0.007659
# 31           0.633000
# 32           0.019024
# 33           0.033300
# 34          28.990000
# 35           0.009392
# 36           0.051815
# 37           2.999444
# 38           0.006013
# 39           0.016500
# 40           0.002881
# 41          15.990000
# 42           1.110000
# 43          29.590000

# %% [markdown]
# Looking at the count for the number of Costco products that are cheaper than RCS:

# %%
rcs_column = shortened_matched_rcs_costco_unitprice['RCS_unit_price']
costco_column = shortened_matched_rcs_costco_unitprice['Costco_unit_price']

# Get count of items where Costco was cheaper than RCS:
costco_column[costco_column < rcs_column].count()
# Out:
# 36

# %%
rcs_column = shortened_matched_rcs_costco_unitprice['RCS_unit_price']
costco_column = shortened_matched_rcs_costco_unitprice['Costco_unit_price']

# Get count of items where Costco was cheaper than RCS:
costco_column[costco_column > rcs_column].count()
# Out:
# 8

# %%
# percent of times that costco is cheaper
costco_column[costco_column < rcs_column].count()/len(shortened_matched_rcs_costco_unitprice)
# Out:
# 0.8181818181818182

# %% [markdown]
# **Costco has 36 items that are cheaper than RCS out of 44 items. This means that 82% of the items are cheaper than Costco.**

# %% [markdown]
# ### It is great to see that Costco is cheaper majority of the time, but for Costco you have to pay a annual fee to shop there. So I was curious if I could quanitify how much cheaper Costco is. If it was just very slightly cheaper, it still would be more worth it to shop at RCS. So we will look at the distribution of the price differences.

# %%
# create column that calculates the price differences for all items (Costco price - RCS price)
# positive means that Costco is more expensive, and negative means Costco is cheaper
price_diff = []

for i in range(len(shortened_matched_rcs_costco_unitprice)):
    price_diff.append(shortened_matched_rcs_costco_unitprice['Costco_unit_price'][i] - shortened_matched_rcs_costco_unitprice['RCS_unit_price'][i])
    
    
shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'] = price_diff
# shortened_matched_rcs_costco_unitprice

# %%
# create two bar charts, one that shows the spread of unit prices (less than 1$) and one that shows the item price difference (more than $1)
range_smaller_1 = shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'].between(-1,1, inclusive='neither')
w = 0.1
tick_list = np.arange(min(shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'][range_smaller_1]), max(shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'][range_smaller_1])+ w,w)


plt.figure(figsize=(30,10))

plt.hist(shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'][range_smaller_1], bins=np.arange(min(shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'][range_smaller_1]), max(shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'][range_smaller_1]) + w, w));
plt.title('Spread of Unit Prices where differences is smaller than $1 \n(Costco price - RCS price)', fontsize = 30)
plt.xlabel('Unit Price', fontsize=20)
plt.ylabel('Count', fontsize=20)
plt.xticks(ticks= tick_list, fontsize=20)
plt.yticks(fontsize=20)
plt.grid();

# %%
list_of_index = []
list_of_index = shortened_matched_rcs_costco_unitprice[shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff']<=-1].index.tolist()
list_of_index += shortened_matched_rcs_costco_unitprice[shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff']>=1].index.tolist()

w = 10
tick_list = np.arange(min(shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'][list_of_index]), max(shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'][list_of_index])+w,w)


plt.figure(figsize=(30,10))

plt.hist(shortened_matched_rcs_costco_unitprice['Costco-RCS_price_diff'][list_of_index])
plt.title('Spread of Unit Prices where differences is greater than $1 \n(Costco price - RCS price)', fontsize = 30)
plt.xlabel('Unit Price', fontsize=20)
plt.ylabel('Count', fontsize=20)
plt.xticks(ticks= tick_list, fontsize=20)
plt.yticks(fontsize=20)
plt.grid();

# %% [markdown]
# I did not feel like the one for less than a $1 difference was very clear, so I decided to change the way I looked at it by finding the average units sold at Costco and multiplying the unit price by the same units for both stores to make it more comparable.

# %%
mean_rcs_price = []
mean_costco_price = []

for i in range(len(shortened_matched_rcs_costco_unitprice)):
    # we want to mutiply the unit price per store by the costco unit amount to be able to equate the amount to determine a quantifiable difference
    if math.isnan(shortened_matched_rcs_costco_unitprice['costco_amount'][i]) == False:
        mean_rcs_price.append(shortened_matched_rcs_costco_unitprice['RCS_unit_price'][i]*shortened_matched_rcs_costco_unitprice['costco_amount'][i]) 
        mean_costco_price.append(shortened_matched_rcs_costco_unitprice['Costco_unit_price'][i]*shortened_matched_rcs_costco_unitprice['costco_amount'][i]) 
        
    # if we have a null in the unit price, it means it is either 1 unit, or we were not given enough information, 
    # so we assume that the unit price will 1 and do not multiple the unit price by any value
    else:
        mean_rcs_price.append(shortened_matched_rcs_costco_unitprice['RCS_unit_price'][i])
        mean_costco_price.append(shortened_matched_rcs_costco_unitprice['Costco_unit_price'][i])        

# here we create columns from our lists to give us the price at each store using the Costco units and the store specific unit price
shortened_matched_rcs_costco_unitprice['mean_rcs_price_(costco_units)'] = mean_rcs_price
shortened_matched_rcs_costco_unitprice['mean_costco_price_(costco_units)'] = mean_costco_price
# now we want to calculate the price difference of the mean price:
shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'] = shortened_matched_rcs_costco_unitprice['mean_costco_price_(costco_units)'] - shortened_matched_rcs_costco_unitprice['mean_rcs_price_(costco_units)']

# shortened_matched_rcs_costco_unitprice

# %%
# I wanted to colour code my histogram by which store was cheaper (difference less than 0 and greater than 0)
# and since we are using a histogram, we need to have two dataframes if we want two colours.
less_than_zero = []
greater_than_zero = []

for i in range(len(shortened_matched_rcs_costco_unitprice)):
    # I included less than or equal to 0 for Costco being cheaper
    if (shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'][i] <= 0):
        less_than_zero.append(i)
    else:
        greater_than_zero.append(i)

# I wanted to have x-ticks at 5$ intervals, so I used np.arange to space them out evenly
w = 5
tick_list = np.arange(min(round(shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'])), max(round(shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)']))+w, w)


plt.figure(figsize=(30,10))

# created a histogram that had all the price differences given the costco units and store specific unit price
plt.hist(x = [shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'][less_than_zero], shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'][greater_than_zero]], bins=44, color = ['green', 'red'])
plt.title('Spread of Price Difference \nwhere units are multiplied by Costco portions', fontsize = 35)
plt.xlabel('Price Difference \n(Costco - RCS price)', fontsize=25)
plt.ylabel('Count', fontsize=25)
plt.xticks(ticks= tick_list, fontsize=20)
plt.yticks(fontsize=20)
plt.legend(['Costco cheaper', 'RCS cheaper'], fontsize=25);

# %%
# mean of price difference when Costco is cheaper
statistics.mean(shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'][less_than_zero])
# Out:
# -21.135285814466016

# %%
statistics.median(shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'][less_than_zero])
# Out:
# -18.52767930327869

# %%
# mean of price difference when RCS is cheaper
statistics.mean(shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'][greater_than_zero])
# Out:
# 23.449075

# %%
statistics.median(shortened_matched_rcs_costco_unitprice['mean_price_diff(costco_units)'][greater_than_zero])
# Out:
# 8.316300000000002

# %% [markdown]
# ----

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# As can be seen, the majority of the spread of the unit price is negative, meaning that the Costco price is cheaper than the RCS (which was confirmed in our previous calculations). We can now see that the average (median due to outliers) price difference is 18.50 when Costco is cheaper, but only 8.30 when RCS is cheaper. On top of that, Costco is 82% more likely to be cheaper. This means that there is a significant savings at Costco. Which would mean that the membership is worth it - given if you shop the deals.

# %% [markdown]
# -----

# %% [markdown]
# # Extension:

# %% [markdown]
# **For fun look at the percent of price differences between the two stores for all matches for both stripped and branded dfs.**
